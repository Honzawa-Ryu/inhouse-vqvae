# %%
from torch import nn
import torch

# %%
A = torch.tensor([[1, 3, 4], [2, 4, 5]])
B = torch.tensor([[5, 2, 1], [3,4,2]] )

# %%
A**2
# Out:
# tensor([[ 1,  9, 16],
#         [ 4, 16, 25]])

# %%
E = nn.Embedding(256, 64)

# %%
(E.weight**2).shape
# Out:
# torch.Size([256, 64])

# %%
C = torch.cat([A, B], 2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 C = torch.cat([A, B], 2)
#
# IndexError: Dimension out of range (expected to be in range of [-2, 1], but got 2)

# %%
print(C)
# Out:
# tensor([[1, 3, 4],
#         [2, 4, 5],
#         [5, 2, 1],
#         [3, 4, 2]])
